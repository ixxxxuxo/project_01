# %% [markdown]
# <a href="https://colab.research.google.com/github/ixxxxuxo/project_01/blob/main/Project_01_%EB%B0%95%EC%83%81%ED%9A%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/vgames2.csv')
df.info()
# 결측치 확인
print(df.isnull().sum())
df.describe()
# 필요없는 열 삭제
df = df.drop(['Unnamed: 0'],axis=1)
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   16598 non-null  int64
#  1   Name         16598 non-null  object
#  2   Platform     16598 non-null  object
#  3   Year         16327 non-null  float64
#  4   Genre        16548 non-null  object
#  5   Publisher    16540 non-null  object
#  6   NA_Sales     16598 non-null  object
#  7   EU_Sales     16598 non-null  object
#  8   JP_Sales     16598 non-null  object
#  9   Other_Sales  16598 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.3+ MB
# Unnamed: 0       0
# Name             0
# Platform         0
# Year           271
# Genre           50
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# dtype: int64
# ...

# %%
# 결측치 제거 
# 결측치 탐색을 해보려고 했으나 실패
df = df.dropna()
df.isnull().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16241 entries, 0 to 16597
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16241 non-null  object
#  1   Platform     16241 non-null  object
#  2   Year         16241 non-null  float64
#  3   Genre        16241 non-null  object
#  4   Publisher    16241 non-null  object
#  5   NA_Sales     16241 non-null  object
#  6   EU_Sales     16241 non-null  object
#  7   JP_Sales     16241 non-null  object
#  8   Other_Sales  16241 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 1.2+ MB

# %%
#지역별 판매량에 이상치가 있는지 확인
print('북미판매량',df['NA_Sales'].unique(),'\n')
print('유럽판매량',df['EU_Sales'].unique(),'\n')
print('일본판매량',df['JP_Sales'].unique(),'\n')
print('기타판매량',df['Other_Sales'].unique(),'\n')
# Out:
# 북미판매량 ['0.04' '0.17' '0' '0.12' '0.02' '0.07' '480K' '0.14' '0.01' '0.57' '0.06'
#  '0.08' '0.48' '0.03' '0.05' '0.29' '0.19' '0.3' '0.26' '0.11' '0.18'
#  '0.33' '0.51' '60K' '0.13' '0.34' '0.25' '0.41' '0.52' '0.22' '0.35'
#  '0.1' '0.67' '0.59' '0.36' '0.21' '1.19' '5.91' '1.98' '0.09' '0K' '0.5'
#  '0.94' '0.16' '0.63' '0.43' '0.2' '1.23' '0.44' '0.42' '0.97' '2.67'
#  '0.28' '6.05' '0.47' '0.49' '0.62' '0.24' '0.72' '1.74' '0.46' '0.65'
#  '0.32' '1.53' '0.23' '0.53' '0.37' '1.26' '0.39' '0.58' '1.94' '2.31'
#  '1.03' '0.82' '0.4' '0.93' '0.56' '0.96' '1.64' '0.69' '1.25' '0.27'
#  '0.92' '0.58M' '1.24' '0.25M' '0.86' '0.73' '0.55' '1.54' '1.02' '1.27'
#  '0.54' '0.15' '1.09' '3.44' '2.29' '0.88' '5.55M' '1.37' '2.3' '0.99'
#  '1.15' '0.98' '0.75' '0.74' '0.7' '0.14M' '0.45' '1.2' '1.41' '0.68'
#  '1.23M' '1.56' '0.31' '1.45' '1.11' '2.9' '0M' '0.83' '0.78' '3.38'
#  '0.64' '1.08' '0.38' '1.47' '0.06M' '0.77' '1.05' '6.85' '3.83' '3.79'
# ...

# %%
import operator
#판매량에서 M은 지우고, K는 0.001을 곱하기
#문자열 지우고 변환해야함
df['K_NA_Sales'] = df['NA_Sales'].str.contains('K',regex = False)
df['K_NA_Sales']

# df['NA_Sales'] = df['NA_Sales'].apply(pd.to_numeric,errors='coerce') 
# df['EU_Sales'] = df['EU_Sales'].apply(pd.to_numeric,errors='coerce') 
# df['JP_Sales'] = df['JP_Sales'].apply(pd.to_numeric,errors='coerce') 
# df['Other_Sales'] = df['Other_Sales'].apply(pd.to_numeric,errors='coerce') 

# print(df['NA_Sales'].dtype)
# print(df['EU_Sales'].dtype)
# print(df['JP_Sales'].dtype)
# print(df['Other_Sales'].dtype)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16593    False
# 16594    False
# 16595    False
# 16596    False
# 16597    False
# Name: K_NA_Sales, Length: 16241, dtype: bool

# %%
#지역별 판매량에 이상치가 있는지 확인
print('북미판매량',df['NA_Sales'].unique(),'\n')
print('유럽판매량',df['EU_Sales'].unique(),'\n')
print('일본판매량',df['JP_Sales'].unique(),'\n')
print('기타판매량',df['Other_Sales'].unique(),'\n')
# Out:
# 북미판매량 ['0.04' '0.17' '0' '0.12' '0.02' '0.07' '480K' '0.14' '0.01' '0.57' '0.06'
#  '0.08' '0.48' '0.03' '0.05' '0.29' '0.19' '0.3' '0.26' '0.11' '0.18'
#  '0.33' '0.51' '60K' '0.13' '0.34' '0.25' '0.41' '0.52' '0.22' '0.35'
#  '0.1' '0.67' '0.59' '0.36' '0.21' '1.19' '5.91' '1.98' '0.09' '0K' '0.5'
#  '0.94' '0.16' '0.63' '0.43' '0.2' '1.23' '0.44' '0.42' '0.97' '2.67'
#  '0.28' '6.05' '0.47' '0.49' '0.62' '0.24' '0.72' '1.74' '0.46' '0.65'
#  '0.32' '1.53' '0.23' '0.53' '0.37' '1.26' '0.39' '0.58' '1.94' '2.31'
#  '1.03' '0.82' '0.4' '0.93' '0.56' '0.96' '1.64' '0.69' '1.25' '0.27'
#  '0.92' '0.58M' '1.24' '0.25M' '0.86' '0.73' '0.55' '1.54' '1.02' '1.27'
#  '0.54' '0.15' '1.09' '3.44' '2.29' '0.88' '5.55M' '1.37' '2.3' '0.99'
#  '1.15' '0.98' '0.75' '0.74' '0.7' '0.14M' '0.45' '1.2' '1.41' '0.68'
#  '1.23M' '1.56' '0.31' '1.45' '1.11' '2.9' '0M' '0.83' '0.78' '3.38'
#  '0.64' '1.08' '0.38' '1.47' '0.06M' '0.77' '1.05' '6.85' '3.83' '3.79'
# ...

# %%
total_sales = pd.DataFrame(data=df,columns=['NA_Sales','EU_Sales','JP_Sales','Other_Sales'])
total_sales
# Out:
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 0         0.04        0        0           0
# 1         0.17        0        0        0.01
# 2            0        0     0.02           0
# 3         0.04        0        0           0
# 4         0.12     0.09        0        0.04
# ...        ...      ...      ...         ...
# 16593     0.15     0.04        0        0.01
# 16594     0.01        0        0           0
# 16595     0.44     0.19     0.03        0.13
# 16596     0.05     0.05     0.25        0.03
# 16597        0        0     0.16        0.01
#
# [16241 rows x 4 columns]

# %%
# 결측치가 중요도를 지니고 있는지 알 수 없으므로 
# 결측치가 있는 행은 삭제하고 분석하기 버전과 
# 결측치를 살려서 분석하기 버전으로 나누기

# %%
drop_df = df.dropna('')

# %%
df.head()

# %% [markdown]
# **Q1.지역에 따라서 선호하는 게임 장르가 다를까**
# - 장르 / 지역별 게임 판매량
# - 비교
# - 가설
# 1) 귀무가설 : 지역에 따라서 선호하는 게임이 다를것이다
# 2) 대안가설 : 지역에 따라서 선호하는 게임이 다르지 않을것이다

# %%
df['NA_Sales'] = pd.to_numeric(df['NA_Sales'],errors='coerce')
df['EU_Sales'] = pd.to_numeric(df['EU_Sales'],errors='coerce')
df['JP_Sales'] = pd.to_numeric(df['JP_Sales'],errors='coerce')
df['Other_Sales'] = pd.to_numeric(df['Other_Sales'],errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3396bf6e3959> in <module>()
# ----> 1 df['NA_Sales'] = pd.to_numeric(df['NA_Sales'],errors='coerce')
#       2 df['EU_Sales'] = pd.to_numeric(df['EU_Sales'],errors='coerce')
#       3 df['JP_Sales'] = pd.to_numeric(df['JP_Sales'],errors='coerce')
#       4 df['Other_Sales'] = pd.to_numeric(df['Other_Sales'],errors='coerce')
#
# NameError: name 'pd' is not defined

# %%
df.info()

# %%
import seaborn as sns

# df.info()
df['Name'] = df['Name'].astype('category')
x = df['Name'].value_counts()

df['Platform'] = df['Platform'].astype('category')
y = df['Platform'].value_counts()
# Total_Sales_Value = df.sum(['NA_Sales','EU_Sales','JP_Sales','Other_Sales'],axis=1)

# Top_Sales_Game= df[Total_Sales_Value].groupby(df['Name'])
# print(Top_Sales_Game)

# %%
df.corr()

# %% [markdown]
# **Q2. 연도별 게임의 트렌드가 있을까**
# - 장르+판매량 추이 / 연도 -> 시계열 그래프 시각화

# %% [markdown]
# **Q3. 매출이 높은 게임에 대한 분석 및 시각화 프로세스**
# - 매출 상위 장르
# - 매출 상위 장르의 지역 판매량
# - 귀무가설 : 매출이 높은 게임은 지역과 관계가 있을것이다
# - 대안가설 : 매출이 높은 게임은 지역과 관계가 없을것이다
#
# - 특정 장르가 매출이 높은가?
